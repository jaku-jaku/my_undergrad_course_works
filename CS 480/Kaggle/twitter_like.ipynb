# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import os

import jx_lib

# %%
DATA_X = pd.read_csv('data/p_train_x.csv')
DATA_Y = pd.read_csv('data/p_train_y.csv')

# %% [markdown]
# ## Pre Data Analysis

# %%
DATA_X.head()
# Out:
#    id      conversation_id               created_at             user_id  \
# 0   0   807288227279306753  2016-12-09 10:18:06 PST  756502711621726209
# 1   1   875332448145616896  2017-06-15 05:41:33 PDT          1582593798
# 2   2  1203887042528206849  2019-12-08 20:00:12 PST           207634580
# 3   3  1139567821820555265  2019-06-14 09:18:35 PDT           228283891
# 4   4  1017123008102719488  2018-07-11 12:06:37 PDT           873936709
#
#           username                  name place  \
# 0  arxiv_in_review       arXiv in review   NaN
# 1      lymphomahub          Lymphoma Hub   NaN
# 2    meetvancouver         Vancouver CVB   NaN
# 3      thegradient        Hossein Mobahi   NaN
# 4      rllabmcgill  Reasoning & Learning   NaN
#
#                                                tweet language  \
# 0  #ICLR2017 Semi-Supervised Detection of Extreme...       en
# 1  #ICML14 #icml2017 @JudithTrotman1 about to pre...       en
# 2  #NeurIPS2019 tip! We put together dining guide...       en
# 3  @roydanroy giving a fantastic talk at #ICML #I...       en
# 4  Congrats to Matt Smith for presenting his pape...       en
#
#                                             mentions  \
# 0                                                 []
# 1  [{'screen_name': 'judithtrotman1', 'name': 'ju...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                 urls  \
# 0                ['http://arxiv.org/abs/1612.02095']
# 1                                                 []
# 2                       ['http://ow.ly/yNeR50xdcYO']
# 3                                                 []
# 4  ['http://proceedings.mlr.press/v80/smith18a.ht...
#
#                                               photos  \
# 0                                                 []
# 1  ['https://pbs.twimg.com/media/DCXONWrWAAAX9Bg....
# 2  ['https://pbs.twimg.com/media/ELUQ4hNXkAACSn1....
# 3  ['https://pbs.twimg.com/media/D9CO3KyVAAErkPU....
# 4  ['https://pbs.twimg.com/media/Dh2LL5HW4AAEi_q....
#
#                                    hashtags cashtags  \
# 0                              ['iclr2017']       []
# 1  ['icml14', 'icml2017', 'lymphoma', 'hl']       []
# 2              ['neurips2019', 'vancouver']       []
# 3            ['icml', 'icml19', 'icml2019']       []
# 4                              ['icml2018']       []
#
#                                                 link quote_url  video  \
# 0  https://twitter.com/arxiv_in_review/status/807...       NaN      0
# 1  https://twitter.com/lymphomahub/status/8753324...       NaN      1
# 2  https://twitter.com/MeetVancouver/status/12038...       NaN      1
# 3  https://twitter.com/TheGradient/status/1139567...       NaN      1
# 4  https://twitter.com/rllabmcgill/status/1017123...       NaN      1
#
#                                          thumbnail reply_to
# 0                                              NaN       []
# 1  https://pbs.twimg.com/media/DCXONWrWAAAX9Bg.jpg       []
# 2  https://pbs.twimg.com/media/ELUQ4hNXkAACSn1.jpg       []
# 3  https://pbs.twimg.com/media/D9CO3KyVAAErkPU.jpg       []
# 4  https://pbs.twimg.com/media/Dh2LL5HW4AAEi_q.jpg       []

# %%
DATA_X.describe()
# Out:
#                  id  conversation_id       user_id         video
# count  55824.000000     5.582400e+04  5.582400e+04  55824.000000
# mean   27911.500000     1.027356e+18  2.859736e+17      0.324663
# std    16115.145051     2.537541e+17  4.217915e+17      0.468253
# min        0.000000     1.807193e+09  1.168000e+03      0.000000
# 25%    13955.750000     9.050883e+17  1.109404e+08      0.000000
# 50%    27911.500000     1.070258e+18  1.426477e+09      0.000000
# 75%    41867.250000     1.205612e+18  7.565027e+17      1.000000
# max    55823.000000     1.362214e+18  1.353092e+18      1.000000

# %%
DATA_Y.head()
# Out:
#    id  likes_count
# 0   0            1
# 1   1            1
# 2   2            1
# 3   3            2
# 4   4            3

# %%
DATA_Y.describe()
# Out:
#                  id   likes_count
# count  55824.000000  55824.000000
# mean   27911.500000      1.518827
# std    16115.145051      1.108261
# min        0.000000      0.000000
# 25%    13955.750000      1.000000
# 50%    27911.500000      2.000000
# 75%    41867.250000      3.000000
# max    55823.000000      3.000000

# %%
DATA_X.plot(kind='box', subplots=True, layout=(4,4), sharex=False,sharey=False ,figsize =(15,15))
plt.show()

# %%
DATA_X.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'user_id', 'username', 'name',
#        'place', 'tweet', 'language', 'mentions', 'urls', 'photos', 'hashtags',
#        'cashtags', 'link', 'quote_url', 'video', 'thumbnail', 'reply_to'],
#       dtype='object')

# %%
category1 = ['conversation_id','user_id']
    
for c in category1:
    jx_lib.bar_plot(DATA_X, c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-007e8e4ae305> in <module>
#       2
#       3 for c in category1:
# ----> 4     jx_lib.bar_plot(DATA_X, c)
#
# TypeError: bar_plot() takes 1 positional argument but 2 were given

# %%
fig, ax = pyplot.subplots(figsize=(18,8))
sns.countplot(x='Age',hue='Outcome',data=data, linewidth=1,ax=ax)

# %%
colors = {0:'#cd1076', 1:'#008080'}
fig, ax = plt.subplots()
grouped = data.groupby('Outcome')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter'
               ,x='BMI', y='Age', label=key
               ,color=colors[key])
plt.show()

# %%
data['Outcome'].value_counts().plot(kind='pie',colors=['#2C4373', '#F2A74B'],autopct='%1.1f%%',figsize=(9,9))
plt.show
varValue = data.Outcome.value_counts()
print(varValue)
